# %% [markdown]
# # 06-kgx-load
#  - reformat for Biolink-compliant Neo4j import using KGX

# %% [markdown]
# #### make the file headers correct for KGX CSV loading
# #### (See https://github.com/NCATS-Tangerine/kgx/blob/RichardBruskiewich-patch-1/data-preparation.md)

# %%
import pandas as pd

# %%
DATA  = 'data/'

NODES_XREF_CSV = DATA+"nodes_xref.csv"
EDGES_BIOLINK_CSV = DATA+"edges_biolink.csv"

NODES_KGX_CSV = "nodes_kgx.csv"
EDGES_KGX_CSV = "edges_kgx.csv"

# %% [markdown]
# ## Nodes

# %%
# https://biolink.github.io/biolink-model/docs/node_property
nodes = pd.read_csv(NODES_XREF_CSV)
nodes.head()
# Out:
#          ID                                       LABEL  umls_type  \
# 0  C3842672                                       Day 7       T033
# 1  C0020684                                Hypoxanthine  T123|T109
# 2  C0853225                               INR Increased       T033
# 3  C1513022                            Mature Centriole       T026
# 4  C0267183  Hourglass stricture or stenosis of stomach       T047
#
#                                   umls_type_label  \
# 0                                         Finding
# 1  Biologically Active Substance|Organic Chemical
# 2                                         Finding
# 3                                  Cell Component
# 4                             Disease or Syndrome
#
#                     blm_category  \
# 0  disease_or_phenotypic_feature
# 1             chemical_substance
# 2  disease_or_phenotypic_feature
# 3                 cell_component
# 4  disease_or_phenotypic_feature
#
#                                                xrefs
# 0                                      LNC:LA16590-4
# 1  LNC:LP15651-0;NCI:C29105;CHV:0000006506;MESH:D...
# 2  OMIM:MTHU055758;NCI_CTCAE:E12175;NCI:C78366;CH...
# 3                                         NCI:C33060
# 4              MTHICD9:537.6;ICD9CM:537.6;DOID:12234

# %%
nodes.blm_category.value_counts()
# Out:
# chemical_substance                57087
# protein                           27274
# disease_or_phenotypic_feature     26634
# gene                              23704
# gross_anatomical_structure         8211
# biological_process_or_activity     7260
# anatomical_entity                  2275
# cell_component                     1673
# cell                               1193
# activity_and_behavior               845
# phenotypic_feature                  252
# genomic_entity                      170
# Name: blm_category, dtype: int64

# %%
nodes.ID = "UMLS:" + nodes.ID
nodes.blm_category = "biolink:" + nodes.blm_category
nodes.xrefs = nodes.xrefs.str.replace(";","|")

# %%
nodes.rename(columns = {'ID': 'id', 
                        'LABEL': 'name', 
                        'blm_category': 'category',
                        'xrefs': 'systematic_synonym'}, inplace=True)

# %%
nodes.head()
# Out:
#               id                                        name  umls_type  \
# 0  UMLS:C3842672                                       Day 7       T033
# 1  UMLS:C0020684                                Hypoxanthine  T123|T109
# 2  UMLS:C0853225                               INR Increased       T033
# 3  UMLS:C1513022                            Mature Centriole       T026
# 4  UMLS:C0267183  Hourglass stricture or stenosis of stomach       T047
#
#                                   umls_type_label  \
# 0                                         Finding
# 1  Biologically Active Substance|Organic Chemical
# 2                                         Finding
# 3                                  Cell Component
# 4                             Disease or Syndrome
#
#                         category  \
# 0  disease_or_phenotypic_feature
# 1             chemical_substance
# 2  disease_or_phenotypic_feature
# 3                 cell_component
# 4  disease_or_phenotypic_feature
#
#                                   systematic_synonym
# 0                                      LNC:LA16590-4
# 1  LNC:LP15651-0|NCI:C29105|CHV:0000006506|MESH:D...
# 2  OMIM:MTHU055758|NCI_CTCAE:E12175|NCI:C78366|CH...
# 3                                         NCI:C33060
# 4              MTHICD9:537.6|ICD9CM:537.6|DOID:12234

# %%
nodes.to_csv(NODES_KGX_CSV, index=False)

# %% [markdown]
# ## EDGES

# %%
# https://biolink.github.io/biolink-model/docs/association_slot
edges = pd.read_csv(EDGES_BIOLINK_CSV)

# %%
edges.head(10)
# Out:
#   SUBJECT_CUI      SEMMED_PRED OBJECT_CUI               PMID    NEG  \
# 0    C1412045          AFFECTS   C0005935           29798367  False
# 1    C1412045          AFFECTS   C0028754           19789049  False
# 2    C1412045          AFFECTS   C0036421  31505074;31505074  False
# 3    C1412045          AFFECTS   C0597304            1409557  False
# 4    C1412045          AFFECTS   C0599816            7617239  False
# 5    C1412045  ASSOCIATED_WITH   C0001807    8503828;8240219  False
# 6    C1412045  ASSOCIATED_WITH   C0007222           26915323  False
# 7    C1412045  ASSOCIATED_WITH   C0009324           22465933  False
# 8    C1412045  ASSOCIATED_WITH   C0010346   1955175;22465933  False
# 9    C1412045  ASSOCIATED_WITH   C0012634           19737390  False
#
#                           bl_pred
# 0                         AFFECTS
# 1                         AFFECTS
# 2                         AFFECTS
# 3                         AFFECTS
# 4                         AFFECTS
# 5                      RELATED_TO
# 6  GENE_ASSOCIATED_WITH_CONDITION
# 7  GENE_ASSOCIATED_WITH_CONDITION
# 8  GENE_ASSOCIATED_WITH_CONDITION
# 9  GENE_ASSOCIATED_WITH_CONDITION

# %%
# fix the CURIES and add 'provided_by' source
edges.SUBJECT_CUI = "UMLS:" + edges.SUBJECT_CUI
edges.OBJECT_CUI = "UMLS:" + edges.OBJECT_CUI
edges.SEMMED_PRED = "semmed:" + edges.SEMMED_PRED
edges.PMID = edges.PMID.map(lambda x: {"PMID:"+y for y in x.split(';')}).apply(lambda x: "|".join(x))
edges.bl_pred = "biolink:"+edges.bl_pred.str.lower()
edges['provided_by'] = "https://ii.nlm.nih.gov/SemRep_SemMedDB_SKR/"

# %%
# relabel the data columns
edges.rename(columns = {'SUBJECT_CUI': 'subject', 
                        'bl_pred': 'edge_label',
                        'OBJECT_CUI': 'object', 
                        'SEMMED_PRED': 'relation',
                        'PMID': 'publications',
                        'NEG': 'negated'
                       }, inplace=True)

# %%
edges.head(10)
# Out:
#          subject                relation         object  \
# 0  UMLS:C1412045          semmed:AFFECTS  UMLS:C0005935
# 1  UMLS:C1412045          semmed:AFFECTS  UMLS:C0028754
# 2  UMLS:C1412045          semmed:AFFECTS  UMLS:C0036421
# 3  UMLS:C1412045          semmed:AFFECTS  UMLS:C0597304
# 4  UMLS:C1412045          semmed:AFFECTS  UMLS:C0599816
# 5  UMLS:C1412045  semmed:ASSOCIATED_WITH  UMLS:C0001807
# 6  UMLS:C1412045  semmed:ASSOCIATED_WITH  UMLS:C0007222
# 7  UMLS:C1412045  semmed:ASSOCIATED_WITH  UMLS:C0009324
# 8  UMLS:C1412045  semmed:ASSOCIATED_WITH  UMLS:C0010346
# 9  UMLS:C1412045  semmed:ASSOCIATED_WITH  UMLS:C0012634
#
#                  publications  negated  \
# 0               PMID:29798367    False
# 1               PMID:19789049    False
# 2               PMID:31505074    False
# 3                PMID:1409557    False
# 4                PMID:7617239    False
# 5   PMID:8503828|PMID:8240219    False
# 6               PMID:26915323    False
# 7               PMID:22465933    False
# 8  PMID:1955175|PMID:22465933    False
# 9               PMID:19737390    False
#
#                                edge_label  \
# 0                         biolink:affects
# 1                         biolink:affects
# 2                         biolink:affects
# 3                         biolink:affects
# 4                         biolink:affects
# 5                      biolink:related_to
# 6  biolink:gene_associated_with_condition
# 7  biolink:gene_associated_with_condition
# 8  biolink:gene_associated_with_condition
# 9  biolink:gene_associated_with_condition
#
#                                    provided_by
# 0  https://ii.nlm.nih.gov/SemRep_SemMedDB_SKR/
# 1  https://ii.nlm.nih.gov/SemRep_SemMedDB_SKR/
# 2  https://ii.nlm.nih.gov/SemRep_SemMedDB_SKR/
# 3  https://ii.nlm.nih.gov/SemRep_SemMedDB_SKR/
# 4  https://ii.nlm.nih.gov/SemRep_SemMedDB_SKR/
# 5  https://ii.nlm.nih.gov/SemRep_SemMedDB_SKR/
# 6  https://ii.nlm.nih.gov/SemRep_SemMedDB_SKR/
# 7  https://ii.nlm.nih.gov/SemRep_SemMedDB_SKR/
# 8  https://ii.nlm.nih.gov/SemRep_SemMedDB_SKR/
# 9  https://ii.nlm.nih.gov/SemRep_SemMedDB_SKR/

# %%
edges.to_csv(EDGES_KGX_CSV, index=False)

# %% [markdown]
# ## At this point, the data should be ready for loading into Neo4j by KGX tools

# %% [raw]
# # notes to copy and set up neo4j
#
# scp -i ~/.ssh/Neo4j-AWSMarketplace-Key.pem nodes_neo4j.csv edges_neo4j.csv ubuntu@34.229.55.225:
#
# ssh -i ~/.ssh/Neo4j-AWSMarketplace-Key.pem ubuntu@34.229.55.225
# # on aws
# sudo su
# neo4j stop
# rm -rf /var/lib/neo4j/data/databases/graph.db
# cd /var/lib/neo4j/import/
# neo4j-admin import --nodes nodes_neo4j.csv --relationships edges_neo4j.csv
# neo4j start
