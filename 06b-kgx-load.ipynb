# %% [markdown]
# # 06b-kgx-load
#  - reformat for Biolink-compliant Neo4j import using KGX

# %% [markdown]
# #### Make the file headers correct for KGX TSV loading
#
# See [KGX TSV Data Format](https://github.com/biolink/kgx/blob/master/specification/kgx-format.md#kgx-format-as-tsv)
#
# Note that the use of the `provided_by` node/slot property is deprecatedin Biolink 2.0 so the KGX, so here below we substitute one of  the new properties, `original_knowledge_source`, with an anticipated **InfoRes** identifier value, with SemMedDb versioning included: `infores:sri-semmeddb.4.3`

# %%
import pandas as pd
from semmeddb_biolink_environment import *

# %% [markdown]
# ## Nodes

# %%
# https://biolink.github.io/biolink-model/docs/node_property
nodes = pd.read_csv(NODES_XREF_TSV, sep='\t')
nodes.head()
# Out:
#          ID                   LABEL  umls_type  \
# 0  C0007952   Personality Character       T041
# 1  C3574797              Pbunavirus       T005
# 2  C0948102  Salivary gland adenoma       T191
# 3  C0210064             quinotolast  T121|T109
# 4  C1416967               MAFF gene       T028
#
#                             umls_type_label       blm_category  \
# 0                            Mental Process           Behavior
# 1                                     Virus      OrganismTaxon
# 2                        Neoplastic Process            Disease
# 3  Pharmacologic Substance|Organic Chemical    MolecularEntity
# 4                            Gene or Genome  NucleicAcidEntity
#
#                                                xrefs
# 0  MESH:D002605;PSY:08470;LCH_NW:sh85022615;MTH:U...
# 1                                       NCBI:1198980
# 2                        CHV:0000053218;MDR:10051636
# 3  INCHIKEY:ZUPLNRDTYQWUHP-UHFFFAOYSA-N;MESH:C074...
# 4                   OMIM:604877;HGNC:6780;MTH:NOCODE

# %%
nodes.blm_category.value_counts()
# Out:
# MolecularEntity                    64203
# OrganismTaxon                      43810
# Disease                            32871
# NucleicAcidEntity                  26630
# Polypeptide                        23054
# Procedure                          13371
# DiseaseOrPhenotypicFeature         12402
# GrossAnatomicalStructure           10880
# PhysiologicalProcess                5632
# MolecularActivity                   4512
# Drug                                4276
# Device                              3843
# AnatomicalEntity                    3532
# PhenotypicFeature                   2561
# CellularComponent                   2519
# Activity                            2165
# InformationContentEntity            2023
# Cell                                1527
# Phenomenon                          1380
# SmallMolecule                       1325
# Behavior                            1213
# Cohort                              1200
# Food                                 773
# PopulationOfIndividualOrganisms      617
# PhysicalEntity                       601
# GeographicLocation                   421
# Agent                                386
# ProcessedMaterial                    288
# Publication                          186
# ComplexMolecularMixture              122
# IndividualOrganism                    73
# BiologicalEntity                      55
# Protein                               49
# Vitamin                               39
# ChemicalMixture                       12
# Event                                  9
# NamedThing                             1
# Name: blm_category, dtype: int64

# %%
nodes.ID = "UMLS:" + nodes.ID
nodes.blm_category = "biolink:" + nodes.blm_category
nodes.xrefs = nodes.xrefs.str.replace(";","|")

# %%
nodes.rename(columns = {'ID': 'id', 
                        'LABEL': 'name', 
                        'blm_category': 'category'}, inplace=True)

# %%
nodes.head()
# Out:
#               id                    name  umls_type  \
# 0  UMLS:C0007952   Personality Character       T041
# 1  UMLS:C3574797              Pbunavirus       T005
# 2  UMLS:C0948102  Salivary gland adenoma       T191
# 3  UMLS:C0210064             quinotolast  T121|T109
# 4  UMLS:C1416967               MAFF gene       T028
#
#                             umls_type_label                   category  \
# 0                            Mental Process           biolink:Behavior
# 1                                     Virus      biolink:OrganismTaxon
# 2                        Neoplastic Process            biolink:Disease
# 3  Pharmacologic Substance|Organic Chemical    biolink:MolecularEntity
# 4                            Gene or Genome  biolink:NucleicAcidEntity
#
#                                                xrefs
# 0  MESH:D002605|PSY:08470|LCH_NW:sh85022615|MTH:U...
# 1                                       NCBI:1198980
# 2                        CHV:0000053218|MDR:10051636
# 3  INCHIKEY:ZUPLNRDTYQWUHP-UHFFFAOYSA-N|MESH:C074...
# 4                   OMIM:604877|HGNC:6780|MTH:NOCODE

# %%
nodes.to_csv(NODES_KGX_TSV, sep='\t', index=False)

# %% [markdown]
# ## EDGES

# %%
# https://biolink.github.io/biolink-model/docs/association_slot
edges = pd.read_csv(EDGES_BIOLINK_TSV, sep='\t')

# %%
edges.head(10)
# Out:
#   SUBJECT_CUI      SEMMED_PRED OBJECT_CUI               PMID    NEG  \
# 0    C1412045          AFFECTS   C0005935           29798367  False
# 1    C1412045          AFFECTS   C0020291            6298464  False
# 2    C1412045          AFFECTS   C0028754           19789049  False
# 3    C1412045          AFFECTS   C0036421  31505074;31505074  False
# 4    C1412045          AFFECTS   C0597304            1409557  False
# 5    C1412045          AFFECTS   C0599816            7617239  False
# 6    C1412045  ASSOCIATED_WITH   C0001807    8503828;8240219  False
# 7    C1412045  ASSOCIATED_WITH   C0007222           26915323  False
# 8    C1412045  ASSOCIATED_WITH   C0009324           22465933  False
# 9    C1412045  ASSOCIATED_WITH   C0010346   1955175;22465933  False
#
#       bl_pred
# 0     affects
# 1     affects
# 2     affects
# 3     affects
# 4     affects
# 5     affects
# 6  related_to
# 7  related_to
# 8  related_to
# 9  related_to

# %%
# fix the CURIES and add 'provided_by' source
edges.SUBJECT_CUI = "UMLS:" + edges.SUBJECT_CUI
edges.OBJECT_CUI = "UMLS:" + edges.OBJECT_CUI
edges.SEMMED_PRED = "SEMMEDDB:" + edges.SEMMED_PRED
edges.PMID = edges.PMID.map(lambda x: {"PMID:"+y for y in x.split(';')}).apply(lambda x: "|".join(x))
edges.bl_pred = "biolink:"+edges.bl_pred
# Biolink Model 2.0 - compliant InfoRes tagging of knowledge sources
edges['original_knowledge_source'] = "infores:sri-semmeddb.4.3"   # formerly set to "https://ii.nlm.nih.gov/SemRep_SemMedDB_SKR/"?

# %%
# relabel the data columns
edges.rename(columns = {'SUBJECT_CUI': 'subject', 
                        'bl_pred': 'predicate',
                        'OBJECT_CUI': 'object', 
                        'SEMMED_PRED': 'relation',
                        'PMID': 'publications',
                        'NEG': 'negated'
                       }, inplace=True)

# %%
edges.head(10)
# Out:
#          subject                  relation         object  \
# 0  UMLS:C1412045          SEMMEDDB:AFFECTS  UMLS:C0005935
# 1  UMLS:C1412045          SEMMEDDB:AFFECTS  UMLS:C0020291
# 2  UMLS:C1412045          SEMMEDDB:AFFECTS  UMLS:C0028754
# 3  UMLS:C1412045          SEMMEDDB:AFFECTS  UMLS:C0036421
# 4  UMLS:C1412045          SEMMEDDB:AFFECTS  UMLS:C0597304
# 5  UMLS:C1412045          SEMMEDDB:AFFECTS  UMLS:C0599816
# 6  UMLS:C1412045  SEMMEDDB:ASSOCIATED_WITH  UMLS:C0001807
# 7  UMLS:C1412045  SEMMEDDB:ASSOCIATED_WITH  UMLS:C0007222
# 8  UMLS:C1412045  SEMMEDDB:ASSOCIATED_WITH  UMLS:C0009324
# 9  UMLS:C1412045  SEMMEDDB:ASSOCIATED_WITH  UMLS:C0010346
#
#                  publications  negated           predicate  \
# 0               PMID:29798367    False     biolink:affects
# 1                PMID:6298464    False     biolink:affects
# 2               PMID:19789049    False     biolink:affects
# 3               PMID:31505074    False     biolink:affects
# 4                PMID:1409557    False     biolink:affects
# 5                PMID:7617239    False     biolink:affects
# 6   PMID:8503828|PMID:8240219    False  biolink:related_to
# 7               PMID:26915323    False  biolink:related_to
# 8               PMID:22465933    False  biolink:related_to
# 9  PMID:22465933|PMID:1955175    False  biolink:related_to
#
#   original_knowledge_source
# 0  infores:sri-semmeddb.4.3
# 1  infores:sri-semmeddb.4.3
# 2  infores:sri-semmeddb.4.3
# 3  infores:sri-semmeddb.4.3
# 4  infores:sri-semmeddb.4.3
# 5  infores:sri-semmeddb.4.3
# 6  infores:sri-semmeddb.4.3
# 7  infores:sri-semmeddb.4.3
# 8  infores:sri-semmeddb.4.3
# 9  infores:sri-semmeddb.4.3

# %%
edges.to_csv(EDGES_KGX_TSV, index=False, sep='\t')

# %% [markdown]
# ## At this point, the SemMedDb node and edge tab separated (TSV) data files should be ready for loading by KGX tools
